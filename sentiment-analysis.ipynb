# %%
# Sentiment Analysis Project:
## Import Libraries
## Load Dataset
## Preprocessing
## Model / Polarity Calculation
## Results
pip install textblob streamlit matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in .\AppData\Roaming\Python\Python312\site-packages (0.20.0)
# Requirement already satisfied: streamlit in .\AppData\Roaming\Python\Python312\site-packages (1.55.0)
# Requirement already satisfied: matplotlib in .\AppData\Roaming\Python\Python312\site-packages (3.10.1)
# Requirement already satisfied: nltk>=3.9 in .\AppData\Roaming\Python\Python312\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (2.2.4)
# Requirement already satisfied: packaging>=20 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\AppData\Roaming\Python\Python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in .\AppData\Roaming\Python\Python312\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\AppData\Roaming\Python\Python312\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.27.1 in .\AppData\Roaming\Python\Python312\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: colorama in .\AppData\Roaming\Python\Python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\AppData\Roaming\Python\Python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\AppData\Roaming\Python\Python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Roaming\Python\Python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Roaming\Python\Python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Roaming\Python\Python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in .\AppData\Roaming\Python\Python312\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in .\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in .\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in .\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: joblib in .\AppData\Roaming\Python\Python312\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\AppData\Roaming\Python\Python312\site-packages (from nltk>=3.9->textblob) (2026.1.15)
# Requirement already satisfied: tqdm in .\AppData\Roaming\Python\Python312\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: six>=1.5 in .\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def analyze_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"
